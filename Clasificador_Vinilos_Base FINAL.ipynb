# %% [markdown]
# # Lectura de los datos de entrenamiento

# %%
#Primer forma de leer nuestros datos, subiendo el archivo manualmente
# !ls
# !unzip leather_dataset.zip
# Out:
# leather_dataset.zip  sample_data
# Archive:  leather_dataset.zip
#    creating: leather_dataset/
#    creating: leather_dataset/Grain off/
#   inflating: leather_dataset/Grain off/Grain off 01 (1).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (10).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (100).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (101).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (102).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (103).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (104).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (105).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (106).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (107).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (108).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (109).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (11).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (110).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (111).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (112).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (113).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (114).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (115).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (116).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (117).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (118).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (119).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (12).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (120).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (121).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (122).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (123).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (124).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (125).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (126).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (127).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (128).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (129).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (13).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (130).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (131).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (132).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (133).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (134).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (135).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (136).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (137).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (138).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (139).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (14).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (140).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (141).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (142).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (143).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (144).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (145).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (146).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (147).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (148).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (149).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (15).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (150).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (151).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (152).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (153).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (154).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (155).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (156).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (157).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (158).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (159).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (16).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (160).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (161).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (162).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (163).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (164).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (165).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (166).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (167).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (168).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (169).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (17).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (170).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (171).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (172).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (173).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (174).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (175).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (176).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (177).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (178).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (179).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (18).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (180).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (181).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (182).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (183).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (184).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (185).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (186).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (187).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (188).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (189).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (19).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (190).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (191).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (192).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (193).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (194).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (195).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (196).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (197).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (198).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (199).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (2).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (20).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (200).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (201).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (202).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (203).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (204).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (205).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (206).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (207).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (208).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (209).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (21).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (210).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (211).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (212).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (213).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (214).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (215).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (216).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (217).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (218).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (219).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (22).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (220).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (221).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (222).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (223).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (224).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (225).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (226).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (227).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (228).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (229).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (23).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (230).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (231).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (232).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (233).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (234).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (235).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (236).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (237).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (238).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (239).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (24).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (240).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (241).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (242).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (243).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (244).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (245).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (246).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (247).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (248).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (249).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (25).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (250).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (251).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (252).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (253).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (254).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (255).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (256).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (257).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (258).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (259).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (26).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (260).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (261).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (262).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (263).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (264).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (265).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (266).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (267).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (268).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (269).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (27).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (270).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (271).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (272).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (273).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (274).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (275).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (276).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (277).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (278).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (279).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (28).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (280).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (281).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (282).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (283).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (284).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (285).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (286).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (287).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (288).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (289).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (29).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (290).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (291).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (292).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (293).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (294).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (295).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (296).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (297).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (298).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (299).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (3).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (30).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (300).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (301).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (302).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (303).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (304).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (305).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (306).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (307).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (308).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (309).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (31).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (310).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (311).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (312).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (313).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (314).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (315).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (316).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (317).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (318).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (319).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (32).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (320).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (321).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (322).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (323).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (324).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (325).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (326).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (327).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (328).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (329).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (33).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (330).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (331).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (332).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (333).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (334).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (335).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (336).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (337).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (338).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (339).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (34).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (340).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (341).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (342).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (343).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (344).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (345).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (346).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (347).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (348).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (349).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (35).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (350).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (351).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (352).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (353).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (354).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (355).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (356).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (357).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (358).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (359).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (36).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (360).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (361).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (362).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (363).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (364).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (365).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (366).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (367).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (368).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (369).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (37).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (370).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (371).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (372).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (373).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (374).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (375).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (376).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (377).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (378).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (379).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (38).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (380).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (381).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (382).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (383).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (384).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (385).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (386).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (387).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (388).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (389).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (39).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (390).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (391).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (392).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (393).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (394).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (395).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (396).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (397).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (398).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (399).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (4).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (40).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (400).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (401).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (402).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (403).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (404).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (405).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (406).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (407).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (408).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (409).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (41).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (410).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (411).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (412).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (413).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (414).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (415).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (416).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (417).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (418).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (419).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (42).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (420).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (421).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (422).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (423).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (424).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (425).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (426).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (427).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (428).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (429).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (43).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (430).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (431).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (432).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (433).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (434).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (435).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (436).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (437).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (438).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (439).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (44).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (440).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (441).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (442).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (443).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (444).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (445).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (446).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (447).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (448).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (449).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (45).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (450).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (451).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (452).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (453).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (454).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (455).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (456).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (457).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (458).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (459).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (46).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (460).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (461).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (462).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (463).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (464).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (465).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (466).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (467).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (468).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (469).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (47).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (470).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (471).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (472).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (473).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (474).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (475).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (476).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (477).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (478).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (479).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (48).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (480).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (481).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (482).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (483).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (484).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (485).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (486).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (487).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (488).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (489).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (49).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (490).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (491).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (492).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (493).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (494).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (495).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (496).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (497).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (498).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (499).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (5).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (50).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (500).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (501).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (502).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (503).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (504).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (505).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (506).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (507).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (508).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (509).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (51).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (510).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (511).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (512).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (513).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (514).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (515).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (516).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (517).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (518).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (519).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (52).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (520).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (521).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (522).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (523).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (524).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (525).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (526).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (527).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (528).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (529).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (53).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (530).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (531).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (532).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (533).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (534).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (535).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (536).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (537).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (538).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (539).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (54).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (540).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (541).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (542).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (543).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (544).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (545).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (546).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (547).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (548).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (549).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (55).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (550).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (551).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (552).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (553).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (554).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (555).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (556).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (557).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (558).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (559).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (56).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (560).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (561).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (562).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (563).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (564).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (565).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (566).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (567).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (568).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (569).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (57).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (570).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (571).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (572).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (573).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (574).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (575).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (576).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (577).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (578).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (579).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (58).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (580).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (581).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (582).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (583).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (584).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (585).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (586).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (587).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (588).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (589).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (59).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (590).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (591).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (592).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (593).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (594).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (595).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (596).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (597).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (598).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (599).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (6).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (60).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (600).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (61).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (62).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (63).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (64).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (65).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (66).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (67).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (68).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (69).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (7).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (70).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (71).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (72).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (73).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (74).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (75).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (76).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (77).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (78).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (79).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (8).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (80).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (81).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (82).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (83).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (84).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (85).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (86).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (87).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (88).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (89).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (9).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (90).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (91).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (92).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (93).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (94).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (95).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (96).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (97).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (98).jpg
#   inflating: leather_dataset/Grain off/Grain off 01 (99).jpg
#    creating: leather_dataset/non defective/
#   inflating: leather_dataset/non defective/Non defective 01 (1).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (10).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (100).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (101).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (102).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (103).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (104).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (105).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (106).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (107).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (108).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (109).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (11).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (110).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (111).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (112).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (113).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (114).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (115).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (116).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (117).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (118).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (119).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (12).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (120).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (121).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (122).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (123).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (124).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (125).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (126).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (127).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (128).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (129).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (13).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (130).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (131).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (132).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (133).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (134).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (135).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (136).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (137).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (138).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (139).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (14).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (140).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (141).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (142).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (143).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (144).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (145).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (146).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (147).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (148).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (149).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (15).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (150).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (151).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (152).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (153).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (154).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (155).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (156).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (157).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (158).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (159).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (16).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (160).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (161).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (162).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (163).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (164).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (165).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (166).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (167).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (168).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (169).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (17).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (170).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (171).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (172).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (173).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (174).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (175).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (176).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (177).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (178).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (179).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (18).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (180).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (181).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (182).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (183).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (184).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (185).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (186).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (187).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (188).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (189).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (19).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (190).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (191).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (192).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (193).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (194).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (195).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (196).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (197).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (198).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (199).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (2).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (20).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (200).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (201).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (202).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (203).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (204).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (205).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (206).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (207).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (208).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (209).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (21).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (210).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (211).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (212).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (213).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (214).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (215).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (216).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (217).jpg
# ...
#   inflating: leather_dataset/non defective/Non defective 01 (439).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (44).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (440).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (441).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (442).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (443).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (444).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (445).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (446).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (447).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (448).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (449).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (45).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (450).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (451).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (452).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (453).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (454).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (455).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (456).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (457).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (458).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (459).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (46).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (460).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (461).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (462).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (463).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (464).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (465).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (466).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (467).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (468).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (469).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (47).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (470).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (471).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (472).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (473).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (474).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (475).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (476).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (477).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (478).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (479).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (48).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (480).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (481).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (482).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (483).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (484).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (485).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (486).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (487).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (488).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (489).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (49).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (490).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (491).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (492).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (493).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (494).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (495).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (496).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (497).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (498).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (499).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (5).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (50).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (500).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (501).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (502).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (503).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (504).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (505).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (506).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (507).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (508).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (509).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (51).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (510).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (511).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (512).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (513).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (514).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (515).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (516).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (517).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (518).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (519).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (52).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (520).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (521).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (522).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (523).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (524).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (525).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (526).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (527).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (528).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (529).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (53).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (530).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (531).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (532).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (533).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (534).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (535).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (536).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (537).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (538).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (539).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (54).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (540).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (541).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (542).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (543).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (544).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (545).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (546).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (547).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (548).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (549).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (55).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (550).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (551).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (552).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (553).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (554).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (555).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (556).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (557).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (558).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (559).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (56).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (560).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (561).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (562).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (563).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (564).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (565).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (566).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (567).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (568).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (569).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (57).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (570).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (571).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (572).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (573).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (574).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (575).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (576).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (577).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (578).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (579).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (58).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (580).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (581).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (582).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (583).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (584).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (585).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (586).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (587).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (588).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (589).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (59).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (590).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (591).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (592).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (593).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (594).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (595).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (596).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (597).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (598).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (599).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (6).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (60).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (600).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (61).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (62).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (63).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (64).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (65).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (66).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (67).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (68).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (69).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (7).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (70).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (71).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (72).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (73).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (74).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (75).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (76).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (77).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (78).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (79).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (8).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (80).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (81).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (82).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (83).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (84).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (85).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (86).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (87).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (88).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (89).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (9).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (90).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (91).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (92).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (93).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (94).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (95).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (96).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (97).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (98).jpg
#   inflating: leather_dataset/non defective/Non defective 01 (99).jpg

# %%
#instalacion de la libreria one drive downloader
# !pip install onedrivedownloader
# Out:
# Collecting onedrivedownloader
#   Downloading onedrivedownloader-1.1.3-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from onedrivedownloader) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from onedrivedownloader) (4.66.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->onedrivedownloader) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->onedrivedownloader) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->onedrivedownloader) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->onedrivedownloader) (2024.8.30)
# Downloading onedrivedownloader-1.1.3-py3-none-any.whl (5.1 kB)
# Installing collected packages: onedrivedownloader
# Successfully installed onedrivedownloader-1.1.3

# %%
# !pip install torch
# !pip install torchvision
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: torch==2.5.1 in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.5.1+cu121)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (11.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch==2.5.1->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.5.1->torchvision) (3.0.2)

# %%
from onedrivedownloader import download

path = "https://tecnube1-my.sharepoint.com/:u:/g/personal/sacalderon_itcr_ac_cr/Efak2SKuFNdJjxOiywHoV5gBQeK2SZEyTk0kQto7Kki3Eg?e=fs6AFI"
#Nombre del archivo
file_name = "leather_dataset.zip"
download(path, file_name, unzip = True, unzip_path = "./leather_dataset_2")
# Out:
# Unzipping file...
# Extracting files: 100%|██████████| 1203/1203 [00:00<00:00, 3211.61it/s]
# './leather_dataset_2'

# %% [markdown]
# ### Trabajo práctico: Varianza descriptor de textura en línea de producción de cuero.

# %%
import torch
from torchvision.datasets import ImageFolder
from torchvision import transforms
import matplotlib.pyplot as plt

# 1. Carga del dataset de imágenes
def cargar_dataset_entrenamiento(ruta_dataset):
    """
    Función que construye el cargador de imágenes en memoria.
    Parámetros:
        ruta_dataset: Ruta del dataset a cargar.
    Retorna:
        cargador_imagenes: Dataset cargado con transformaciones aplicadas.
    """
    transformaciones = transforms.Compose([
        transforms.Resize((223, 223)),  # Redimensiona las imágenes
        transforms.Grayscale(),         # Convierte a escala de grises
        transforms.ToTensor()           # Convierte la imagen en un tensor
    ])
    cargador_imagenes = ImageFolder(ruta_dataset, transform=transformaciones)
    return cargador_imagenes

# Ruta del dataset (modifica esta ruta según tu entorno)
ruta_dataset = "./leather_dataset_2/leather_dataset/"
cargador_imagenes = cargar_dataset_entrenamiento(ruta_dataset)


# 2. Cálculo de desviaciones estándar por categoría
def calcular_desviaciones_por_categoria(cargador, etiqueta):
    """
    Calcula las desviaciones estándar para una categoría específica.
    Parámetros:
        cargador: Dataset cargado.
        etiqueta: Índice de la etiqueta (0 para defectuoso, 1 para no defectuoso).
    Retorna:
        desviaciones: Lista de desviaciones estándar para la categoría.
    """
    desviaciones = []
    for imagen, lbl in cargador:
        if lbl == etiqueta:
            desviaciones.append(torch.std(imagen).item())  # Calcula desviación estándar
    return desviaciones

# 3. Graficar histogramas de desviaciones estándar
def graficar_histogramas(desviaciones_def, desviaciones_no_def):
    """
    Grafica los histogramas de las desviaciones estándar por categoría.
    """
    plt.figure(figsize=(8,6))
    plt.subplot(1, 2, 1)
    plt.hist(desviaciones_def, bins=20, alpha=0.7, color='red', width=0.0011)
    plt.title("Textiles con defectos")
    plt.xlabel("Desviación estándar")
    plt.ylabel("Frecuencia")

    plt.subplot(1, 2, 2)
    plt.hist(desviaciones_no_def, bins=20, alpha=0.7, color='green', width=0.0015)
    plt.title("Textiles sin defectos")
    plt.xlabel("Desviación estándar")
    plt.ylabel("Frecuencia")

    plt.tight_layout()
    plt.show()

def calcular_histograma_desviaciones_estandar(cargador):
    # Calcular desviaciones estándar para cada categoría
    desviaciones_defectuosas = calcular_desviaciones_por_categoria(cargador_imagenes, 0)
    desviaciones_no_defectuosas = calcular_desviaciones_por_categoria(cargador_imagenes, 1)

    # Graficar histogramas
    graficar_histogramas(desviaciones_defectuosas, desviaciones_no_defectuosas)

calcular_histograma_desviaciones_estandar(cargador_imagenes)

# Convertir las desviaciones estándar en tensores
def train_model(desviaciones_defectuosas,desviaciones_no_defectuosas):

    tensor_defectuosas = torch.tensor(desviaciones_defectuosas)
    tensor_no_defectuosas = torch.tensor(desviaciones_no_defectuosas)

    # 4. Calcular parámetros Gaussianos
    mu_defectuosas = torch.mean(tensor_defectuosas)
    sigma_defectuosas = torch.std(tensor_defectuosas)

    mu_no_defectuosas = torch.mean(tensor_no_defectuosas)
    sigma_no_defectuosas = torch.std(tensor_no_defectuosas)
    print("varianza promedio (μ) defectuosas: ",mu_defectuosas)
    print("desviación estándar de la varianza (σ) defectuosas: ",sigma_defectuosas)
    print("varianza promedio (μ) no defectuosas: ",mu_no_defectuosas)
    print("desviación estándar de la varianza (σ) no defectuosas: ",sigma_no_defectuosas)

train_model(desviaciones_defectuosas,desviaciones_no_defectuosas)

# 5. Generar curvas Gaussianas
def calcular_curvas(mu1, sigma1, mu2, sigma2):
    """
    Calcula y grafica las curvas Gaussianas para dos distribuciones.
    Parámetros:
        mu1, sigma1: Media y desviación estándar de la primera distribución (con defectos).
        mu2, sigma2: Media y desviación estándar de la segunda distribución (sin defectos).
    """
    x = torch.linspace(min(mu1 - 3 * sigma1, mu2 - 3 * sigma2), max(mu1 + 3 * sigma1, mu2 + 3 * sigma2), 100)

    y1 = (1 / (sigma1 * torch.sqrt(torch.tensor(2 * torch.pi)))) * torch.exp(-0.5 * ((x - mu1) / sigma1) ** 2)
    y2 = (1 / (sigma2 * torch.sqrt(torch.tensor(2 * torch.pi)))) * torch.exp(-0.5 * ((x - mu2) / sigma2) ** 2)
    transposed_curve = y2 - y1

    # Graficar las curvas
    plt.figure(figsize=(9.15,6))
    plt.plot(x.numpy(), y1.numpy(), label=f"Con defectos (μ={mu1.item():.3f}, σ={sigma1.item():.3f})", color='red')
    plt.plot(x.numpy(), y2.numpy(), label=f"Sin defectos (μ={mu2.item():.3f}, σ={sigma2.item():.3f})", color='green')
    plt.plot(x.numpy(), transposed_curve.numpy(), label="Transposición (Sin defectos - Con defectos)", color='blue', linestyle='dashed')
    plt.xlabel("x")
    plt.ylabel("Densidad de Probabilidad")
    plt.title("Curvas Gaussianas")
    plt.legend()
    plt.grid(True)
    plt.show()

# Graficar
calcular_curvas(mu_defectuosas, sigma_defectuosas, mu_no_defectuosas, sigma_no_defectuosas)
# Out:
# varianza promedio (μ) defectuosas:  tensor(0.0183)
# desviación estándar de la varianza (σ) defectuosas:  tensor(0.0067)
# varianza promedio (μ) no defectuosas:  tensor(0.0284)
# desviación estándar de la varianza (σ) no defectuosas:  tensor(0.0105)

# %%
## CODIGO ORIGINAL ####


def calcular_desviaciones_por_categoria(cargador, etiqueta):
    """
    Calcula las desviaciones estándar para una categoría específica.
    Parámetros:
        cargador: Dataset cargado.
        etiqueta: Índice de la etiqueta (0 para defectuoso, 1 para no defectuoso).
    Retorna:
        desviaciones: Lista de desviaciones estándar para la categoría.
    """
    desviaciones = []
    for imagen, lbl in cargador:
        if lbl == etiqueta:
            desviaciones.append(torch.std(imagen).item())  # Calcula desviación estándar
    return desviaciones

# Calcular desviaciones estándar para cada categoría
desviaciones_defectuosas = calcular_desviaciones_por_categoria(cargador_imagenes, 0)
desviaciones_no_defectuosas = calcular_desviaciones_por_categoria(cargador_imagenes, 1)

# 3. Graficar histogramas de desviaciones estándar
def graficar_histogramas(desviaciones_def, desviaciones_no_def):
    """
    Grafica los histogramas de las desviaciones estándar por categoría.
    """
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.hist(desviaciones_def, bins=20, alpha=0.7, color='red', width=0.0011)
    plt.title("Textiles con defectos")
    plt.xlabel("Desviación estándar")
    plt.ylabel("Frecuencia")

    plt.subplot(1, 2, 2)
    plt.hist(desviaciones_no_def, bins=20, alpha=0.7, color='green', width=0.0015)
    plt.title("Textiles sin defectos")
    plt.xlabel("Desviación estándar")
    plt.ylabel("Frecuencia")

    plt.tight_layout()
    plt.show()

# Graficar histogramas
graficar_histogramas(desviaciones_defectuosas, desviaciones_no_defectuosas)

# Convertir las desviaciones estándar en tensores
tensor_defectuosas = torch.tensor(desviaciones_defectuosas)
tensor_no_defectuosas = torch.tensor(desviaciones_no_defectuosas)

# 4. Calcular parámetros Gaussianos
mu_defectuosas = torch.mean(tensor_defectuosas)
sigma_defectuosas = torch.std(tensor_defectuosas)

mu_no_defectuosas = torch.mean(tensor_no_defectuosas)
sigma_no_defectuosas = torch.std(tensor_no_defectuosas)

# 5. Generar curvas Gaussianas
def calcular_curvas(mu1, sigma1, mu2, sigma2):
    """
    Calcula y grafica las curvas Gaussianas para dos distribuciones.
    Parámetros:
        mu1, sigma1: Media y desviación estándar de la primera distribución (con defectos).
        mu2, sigma2: Media y desviación estándar de la segunda distribución (sin defectos).
    """
    x = torch.linspace(min(mu1 - 3 * sigma1, mu2 - 3 * sigma2), max(mu1 + 3 * sigma1, mu2 + 3 * sigma2), 100)

    y1 = (1 / (sigma1 * torch.sqrt(torch.tensor(2 * torch.pi)))) * torch.exp(-0.5 * ((x - mu1) / sigma1) ** 2)
    y2 = (1 / (sigma2 * torch.sqrt(torch.tensor(2 * torch.pi)))) * torch.exp(-0.5 * ((x - mu2) / sigma2) ** 2)
    transposed_curve = y2 - y1

    # Graficar las curvas
    plt.figure(figsize=(10, 6))
    plt.plot(x.numpy(), y1.numpy(), label=f"Con defectos (μ={mu1.item():.3f}, σ={sigma1.item():.3f})", color='red')
    plt.plot(x.numpy(), y2.numpy(), label=f"Sin defectos (μ={mu2.item():.3f}, σ={sigma2.item():.3f})", color='green')
    plt.plot(x.numpy(), transposed_curve.numpy(), label="Transposición (Sin defectos - Con defectos)", color='blue', linestyle='dashed')
    plt.xlabel("x")
    plt.ylabel("Densidad de Probabilidad")
    plt.title("Curvas Gaussianas")
    plt.legend()
    plt.grid(True)
    plt.show()

# Graficar
calcular_curvas(mu_defectuosas, sigma_defectuosas, mu_no_defectuosas, sigma_no_defectuosas)
